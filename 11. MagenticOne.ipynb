# %%
# !pip install autogen-agentchat 'autogen-ext[magentic-one,openai]'
# !playwright install --with-deps chromium

# %%
# !pip install playwright

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import asyncio
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.teams import MagenticOneGroupChat
from autogen_agentchat.ui import Console


async def main() -> None:
    model_client = OpenAIChatCompletionClient(model="gpt-4o-mini")

    assistant = AssistantAgent(
        "Assistant",
        model_client=model_client,
    )
    team = MagenticOneGroupChat([assistant], model_client=model_client)
    await Console(team.run_stream(task="Write a python program to get transcripts of video urls"))


await main()
# Out:
# ---------- user ----------
# Write a python program to get transcripts of video urls
# ---------- MagenticOneOrchestrator ----------
#
# We are working to address the following user request:
#
# Write a python program to get transcripts of video urls
#
#
# To answer this request we have assembled the following team:
#
# Assistant: An agent that provides assistance with ability to use tools.
#
#
# Here is an initial fact sheet to consider:
#
# 1. GIVEN OR VERIFIED FACTS
#    - The request is to write a Python program.
#
# 2. FACTS TO LOOK UP
#    - The method or library required to obtain transcripts from video URLs. This may involve looking up information related to APIs or libraries like `youtube-transcript-api` or how to interact with video platforms' APIs (e.g., YouTube, Vimeo).
#
# 3. FACTS TO DERIVE
#    - The specific format and structure of the video URLs that will be supported by the program, as different platforms may have varying URL formats.
#    - Whether the video URLs require authorization or special permissions to access transcripts.
#
# 4. EDUCATED GUESSES
#    - The program will likely need to handle various video platforms (most likely popular ones such as YouTube), so it may need to incorporate multiple methods or libraries for transcript extraction.
#    - The output of the program may need to allow for flexibility in formats, such as returning transcripts as text or saving them to a file.
#
#
# Here is the plan to follow as best as possible:
#
# - Research available Python libraries that can extract transcripts from video URLs, focusing on options like `youtube-transcript-api` for YouTube videos.
# - Determine the necessary permissions and API requirements for accessing transcripts, especially for platforms that may restrict access (e.g., authentication tokens).
# - Develop a function that accepts a video URL as input and handles the logic for retrieving the transcript, implementing error handling for various scenarios (e.g., video not found, no transcript available).
# - Format the retrieved transcript in a user-friendly manner, allowing for options to print to the console or save to a file.
# - Test the program with various video URLs to ensure robustness and accuracy of transcript retrieval.
#
# ---------- MagenticOneOrchestrator ----------
# Could you please write a Python program using the youtube-transcript-api library to retrieve transcripts from YouTube video URLs?
# ---------- Assistant ----------
# Here’s a simple Python program that uses the `youtube-transcript-api` library to retrieve transcripts from YouTube video URLs:
#
# ```python
# from youtube_transcript_api import YouTubeTranscriptApi
# from youtube_transcript_api.formatters import TextFormatter
#
# def get_transcript(video_url):
#     try:
#         # Extract video ID from the URL
#         video_id = video_url.split("v=")[1].split("&")[0]
#
#         # Retrieve the transcript using the video ID
#         transcript = YouTubeTranscriptApi.get_transcript(video_id)
#
#         # Format the transcript as plain text
#         formatter = TextFormatter()
#         formatted_transcript = formatter.format_transcript(transcript)
#
#         return formatted_transcript
#
#     except Exception as e:
#         return str(e)
#
# if __name__ == "__main__":
#     url = input("Enter YouTube video URL: ")
#     transcript = get_transcript(url)
#     print("Transcript:\n", transcript)
# ```
#
# ### Instructions to Run the Program:
# 1. Ensure you have Python installed on your system.
# 2. Install the `youtube-transcript-api` package if you haven't already:
#    ```bash
#    pip install youtube-transcript-api
#    ```
# 3. Copy and paste the above program into a Python file, e.g., `get_transcript.py`.
# 4. Run the program:
#    ```bash
#    python get_transcript.py
#    ```
# 5. Input a YouTube video URL when prompted.
#
# ### Notes:
# - This program extracts the video ID from the provided URL and retrieves the transcript.
# - It formats the transcript in plain text.
# - Error handling is included to manage cases where the transcript may not be available.
#
# TERMINATE
# ---------- MagenticOneOrchestrator ----------
# Here’s a Python program that retrieves transcripts from YouTube video URLs using the `youtube-transcript-api` library:
#
# ```python
# from youtube_transcript_api import YouTubeTranscriptApi
# from youtube_transcript_api.formatters import TextFormatter
#
# def get_transcript(video_url):
#     try:
#         # Extract video ID from the URL
#         video_id = video_url.split("v=")[1].split("&")[0]
#
#         # Retrieve the transcript using the video ID
#         transcript = YouTubeTranscriptApi.get_transcript(video_id)
#
#         # Format the transcript as plain text
#         formatter = TextFormatter()
#         formatted_transcript = formatter.format_transcript(transcript)
#
#         return formatted_transcript
#
#     except Exception as e:
#         return str(e)
#
# if __name__ == "__main__":
#     url = input("Enter YouTube video URL: ")
#     transcript = get_transcript(url)
#     print("Transcript:\n", transcript)
# ```
#
# ### How to Use the Program:
# 1. Make sure you have Python installed on your computer.
# 2. Install the `youtube-transcript-api` package using the following command:
#    ```bash
#    pip install youtube-transcript-api
#    ```
# 3. Save the code above in a Python file, for example, `get_transcript.py`.
# 4. Run the program in your terminal or command prompt:
#    ```bash
#    python get_transcript.py
#    ```
# 5. When prompted, enter the YouTube video URL for which you want the transcript.
#
# ### Important Notes:
# - The program extracts the video ID from the provided URL and retrieves the transcript.
# - It formats the transcript into plain text for easy reading.
# - If there are any errors (such as no transcript being available), the program will inform you.
#
# Feel free to ask any questions if you need further assistance!
